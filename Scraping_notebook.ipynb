# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### Step 1: Obtaining our Data

# %%
base_url = "https://naivas.online/pest-control"
carrefour = "https://www.carrefour.ke/mafken/en/"
carrefour_soap = "https://www.carrefour.ke/mafken/en/c/NFKEN2080000"
naivas = "https://naivas.online/"
glovo = "https://glovoapp.com/ke/en/nairobi/?utm_source=google&utm_medium=cpc&utm_campaign=google_search_brandprotection_newusers_KE_Exact_digitalbudget_english&utm_campaignid=2059513152&utm_adgroupid=80144567270&utm_term=glovo&utm_matchtype=e&utm_device=c&gad_source=1&gclid=Cj0KCQjw8J6wBhDXARIsAPo7QA9Jr4tGJ_wTobmeCO3L7Cwez-AKopdYoD1ojb5bUO2kXkSLKucjCEMaArJsEALw_wcB"
jumia = "https://www.jumia.co.ke/"

headers = {
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
}

# %%
page = requests.get(carrefour_soap)
page
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 2: Parsing

# %%
# import urllib3

# urllib3.disable_warnings()

soup = BeautifulSoup(page.content, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="LTR" lang="en-KEN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Carrefour maf uae Site" property="og:site_name"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no, maximum-scale=1" name="viewport"/>
#   <link href="https://www.carrefouruae.com/_ui/responsive/theme-blue/images/16-web.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://www.carrefouruae.com/_ui/responsive/theme-blue/images/32-web.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.carrefouruae.com/_ui/responsive/theme-blue/images/64-web.png" rel="icon" sizes="64x64" type="image/png"/>
#   <link href="https://www.carrefouruae.com/_ui/responsive/theme-blue/images/128-web.png" rel="icon" sizes="128x128" type="image/png"/>
#   <meta content="en" property="og:locale"/>
# ...

# %%
results_div = soup.find_all('div')
len(results_div)
# Out:
# 250

# %%
results = soup.find_all('div', attrs={'class':'tag', 'href': '/tag/change/page/1/'})[0].get_text()
results

# %%
productlist = soup.find_all('div', class_="css-yqd9tx")
productlist
# Out:
# []
